# %% [markdown]
# <h1>Context analysis</h1>
#
# This notebook will explore the context of the app usage. This will be done by:
# <ul>
#     <li>Identifying how many permissions each app is requesting</li>
#     <li>Identify how many permissions are approved for each app</li>
#     <li>Identifying which apps request the same permission but have different response</li>
# </ul>

# %% [markdown]
# <h2>1. Importing modules </h2>
#
# Pandas is required in order to manage the dataframe
# Numpy is used to handle numpy arrays
# os and path are used to access particular files

# %%
import pandas as pd

# %%
df = pd.read_csv("context.csv")
df = df.drop(columns = ['Unnamed: 3'])
df.columns = ["app", "permission", "response"]
print(df)
# Out:
#                           app  \
# 0     Qualcomm MobileSecurity
# 1     Qualcomm MobileSecurity
# 2                     YouTube
# 3                     YouTube
# 4                     YouTube
# ...                       ...
# 3522            Android Setup
# 3523            Android Setup
# 3524            Android Setup
# 3525            Android Setup
# 3526            Android Setup
#
#                                              permission  response
# 0               android.permission.ACCESS_NETWORK_STATE      True
# 1             android.permission.RECEIVE_BOOT_COMPLETED      True
# 2                      android.permission.READ_CONTACTS     False
# 3                       android.permission.GET_ACCOUNTS     False
# 4      com.sonyericsson.home.permission.BROADCAST_BADGE     False
# ...                                                 ...       ...
# 3522         android.permission.GET_ACCOUNTS_PRIVILEGED      True
# 3523                  android.permission.WRITE_CONTACTS      True
# 3524           android.permission.READ_EXTERNAL_STORAGE      True
# 3525  com.google.android.setupwizard.READ_DEVICE_ORI...      True
# 3526  com.google.android.providers.gsf.permission.RE...      True
#
# [3527 rows x 3 columns]

# %%
appPerms = pd.DataFrame(columns = ["App", "Perms"])

for app in df.app.unique():
    appDF = df[df["app"] == app]
    lenAppPerm = len(appPerms)
    appPerms.at[lenAppPerm, "App"] = app
    appPerms.at[lenAppPerm, "Perms"] = len(appDF)

print(appPerms)
# Out:
#                             App Perms
# 0       Qualcomm MobileSecurity     2
# 1                       YouTube    33
# 2      Android Services Library     1
# 3    Phone and MessagingStorage     7
# 4                        Google    98
# ..                          ...   ...
# 187          com.qualcomm.embms     3
# 188            Contacts Storage    15
# 189                  MapPartner     3
# 190          CaptivePortalLogin     5
# 191                      Gboard    21
#
# [192 rows x 2 columns]

# %%
appPermsResponse = pd.DataFrame(columns = ["App", "PermsApproved", "PermsRejected"])

apps = df.app.unique()

for app in apps:
    appDF = df[df["app"] == app]
    responseDF = appDF[appDF["response"] == True]
    lenAppPerm = len(appPermsResponse)
    appPermsResponse.at[lenAppPerm, "App"] = app
    appPermsResponse.at[lenAppPerm, "PermsApproved"] = len(responseDF)
    appPermsResponse.at[lenAppPerm, "PermsRejected"] = len(appDF) - len(responseDF)

print(appPermsResponse)
# Out:
#                             App PermsApproved PermsRejected
# 0       Qualcomm MobileSecurity             2             0
# 1                       YouTube            17            16
# 2      Android Services Library             1             0
# 3    Phone and MessagingStorage             7             0
# 4                        Google            83            15
# ..                          ...           ...           ...
# 187          com.qualcomm.embms             3             0
# 188            Contacts Storage            15             0
# 189                  MapPartner             3             0
# 190          CaptivePortalLogin             5             0
# 191                      Gboard            16             5
#
# [192 rows x 3 columns]

# %%
permsDF = pd.DataFrame(columns = ["permission", "rejected", "rApps", "accepted", "aApps"])

permissions = df.permission.unique()
print(len(permissions))


for permission in permissions:
    permDF = df[df.permission == permission]
    lenPerms = len(permsDF)
    permsDF.at[lenPerms,"permission"] = permission
    permsDF.at[lenPerms,"rejected"] = len(permDF[permDF["response"] == False])
    permsDF.at[lenPerms,"rApps"] = permDF[permDF["response"] == False].app.values
    permsDF.at[lenPerms,"accepted"] = len(permDF[permDF["response"] == True])
    permsDF.at[lenPerms,"aApps"] = permDF[permDF["response"] == True].app.values    
    
for i, row in permsDF.iterrows():
    print(row)
# Out:
# 752
# permission              android.permission.ACCESS_NETWORK_STATE
# rejected                                                      0
# rApps                                                        []
# accepted                                                    110
# aApps         [Qualcomm MobileSecurity, YouTube, Google, com...
# Name: 0, dtype: object
# permission            android.permission.RECEIVE_BOOT_COMPLETED
# rejected                                                      0
# rApps                                                        []
# accepted                                                    115
# aApps         [Qualcomm MobileSecurity, YouTube, Google, com...
# Name: 1, dtype: object
# permission                     android.permission.READ_CONTACTS
# rejected                                                     18
# rApps         [YouTube, Google Play Store, Google Indic Keyb...
# accepted                                                     28
# aApps         [Google, Telegram, WhatsApp, Messages, Confere...
# Name: 2, dtype: object
# permission                      android.permission.GET_ACCOUNTS
# rejected                                                     29
# rApps         [YouTube, Indeed Job Search, WeChat, Google In...
# accepted                                                     22
# aApps         [Google, Calendar Storage, Telegram, WhatsApp,...
# Name: 3, dtype: object
# permission     com.sonyericsson.home.permission.BROADCAST_BADGE
# rejected                                                     13
# rApps         [YouTube, Telegram, WhatsApp, Messages, Google...
# accepted                                                      0
# aApps                                                        []
# Name: 4, dtype: object
# permission            com.htc.launcher.permission.READ_SETTINGS
# rejected                                                     13
# rApps         [YouTube, Telegram, WhatsApp, Messages, Google...
# accepted                                                      0
# aApps                                                        []
# Name: 5, dtype: object
# permission                android.permission.FOREGROUND_SERVICE
# rejected                                                      0
# rApps                                                        []
# accepted                                                     46
# aApps         [YouTube, Google, Telegram, Usage Logger, Down...
# Name: 6, dtype: object
# permission               android.permission.SYSTEM_ALERT_WINDOW
# rejected                                                      3
# rApps                             [Telegram, WeChat, Translate]
# accepted                                                     18
# aApps         [YouTube, Google, Android AccessibilitySuite, ...
# Name: 7, dtype: object
# permission    android.permission.MANAGE_DOCUMENTS
# rejected                                        2
# rApps              [YouTube, Autodesk SketchBook]
# accepted                                        1
# aApps                                 [Downloads]
# Name: 8, dtype: object
# permission                               android.permission.NFC
# rejected                                                      0
# rApps                                                        []
# accepted                                                     27
# aApps         [YouTube, Google, WhatsApp, Authenticator, Goo...
# Name: 9, dtype: object
# permission            android.permission.WRITE_EXTERNAL_STORAGE
# rejected                                                     31
# rApps         [YouTube, Indeed Job Search, QRCode, Weather s...
# accepted                                                     46
# aApps         [Phone and MessagingStorage, Google, Calendar ...
# Name: 10, dtype: object
# permission              android.permission.ACCESS_FINE_LOCATION
# rejected                                                     21
# rApps         [YouTube, Telegram, QRCode, Messages, Weather ...
# accepted                                                     20
# aApps         [Google, com.quicinc.cne.CNEService.CNEService...
# Name: 11, dtype: object
# permission            android.permission.ACCESS_COARSE_LOCATION
# rejected                                                     24
# rApps         [YouTube, Telegram, Indeed Job Search, Message...
# accepted                                                     23
# aApps         [Google, com.quicinc.cne.CNEService.CNEService...
# Name: 12, dtype: object
# permission      com.sec.android.provider.badge.permission.WRITE
# rejected                                                     14
# rApps         [YouTube, Telegram, WhatsApp, Messages, Google...
# accepted                                                      0
# aApps                                                        []
# Name: 13, dtype: object
# permission       com.sec.android.provider.badge.permission.READ
# rejected                                                     14
# rApps         [YouTube, Telegram, WhatsApp, Messages, Google...
# accepted                                                      0
# aApps                                                        []
# Name: 14, dtype: object
# permission                         android.permission.WAKE_LOCK
# rejected                                                      0
# rApps                                                        []
# accepted                                                     99
# aApps         [YouTube, Google, Calendar Storage, Telegram, ...
# Name: 15, dtype: object
# permission                 android.permission.ACCESS_WIFI_STATE
# rejected                                                      0
# rApps                                                        []
# accepted                                                     60
# aApps         [YouTube, Google, Telegram, Indeed Job Search,...
# Name: 16, dtype: object
# permission                   android.permission.USE_FINGERPRINT
# rejected                                                      0
# rApps                                                        []
# accepted                                                     16
# aApps         [YouTube, Google, Telegram, WhatsApp, Google P...
# Name: 17, dtype: object
# permission    com.google.android.gms.permission.AD_ID_NOTIFI...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      2
# aApps                              [YouTube, Google Play Store]
# Name: 18, dtype: object
# permission                   android.permission.MANAGE_ACCOUNTS
# rejected                                                      0
# rApps                                                        []
# accepted                                                     36
# aApps         [YouTube, Google, Calendar Storage, Telegram, ...
# Name: 19, dtype: object
# permission           com.google.android.c2dm.permission.RECEIVE
# rejected                                                      0
# rApps                                                        []
# accepted                                                     44
# aApps         [YouTube, Google, Telegram, Indeed Job Search,...
# Name: 20, dtype: object
# permission    com.google.android.providers.gsf.permission.RE...
# rejected                                                      0
# rApps                                                        []
# accepted                                                     50
# aApps         [YouTube, Google, Telegram, WhatsApp, Messages...
# Name: 21, dtype: object
# permission                  android.permission.GET_PACKAGE_SIZE
# rejected                                                      0
# rApps                                                        []
# accepted                                                     32
# aApps         [YouTube, Google, Messages, Google Play Store,...
# Name: 22, dtype: object
# permission                           android.permission.VIBRATE
# rejected                                                      0
# rApps                                                        []
# accepted                                                     52
# aApps         [YouTube, Google, Telegram, Indeed Job Search,...
# Name: 23, dtype: object
# permission                      android.permission.RECORD_AUDIO
# rejected                                                     14
# rApps         [YouTube, Telegram, Android AccessibilitySuite...
# accepted                                                     15
# aApps         [Google, WhatsApp, Messages, WeChat, Camera, F...
# Name: 24, dtype: object
# permission    com.google.android.youtube.permission.C2D_MESSAGE
# rejected                                                      0
# rApps                                                        []
# accepted                                                      1
# aApps                                                 [YouTube]
# Name: 25, dtype: object
# permission    com.sonymobile.home.permission.PROVIDER_INSERT...
# rejected                                                     13
# rApps         [YouTube, Telegram, WhatsApp, Messages, Google...
# accepted                                                      0
# aApps                                                        []
# Name: 26, dtype: object
# permission          com.htc.launcher.permission.UPDATE_SHORTCUT
# rejected                                                     13
# rApps         [YouTube, Telegram, WhatsApp, Messages, Google...
# accepted                                                      0
# aApps                                                        []
# Name: 27, dtype: object
# permission                          android.permission.INTERNET
# rejected                                                      0
# rApps                                                        []
# accepted                                                    117
# aApps         [YouTube, Google, com.hmdglobal.datago, Calend...
# Name: 28, dtype: object
# permission                   android.permission.USE_CREDENTIALS
# rejected                                                      0
# rApps                                                        []
# accepted                                                     41
# aApps         [YouTube, Google, Calendar Storage, Indeed Job...
# Name: 29, dtype: object
# permission                            android.permission.CAMERA
# rejected                                                     17
# rApps         [YouTube, Google, Telegram, QRCode, Amazon Ale...
# accepted                                                     21
# aApps         [Usage Logger, WhatsApp, Authenticator, Messag...
# Name: 30, dtype: object
# permission             android.permission.READ_EXTERNAL_STORAGE
# rejected                                                     45
# rApps         [YouTube, Indeed Job Search, QRCode, HTML View...
# accepted                                                     55
# aApps         [Phone and MessagingStorage, Google, Calendar ...
# Name: 31, dtype: object
# permission                  android.permission.READ_PHONE_STATE
# rejected                                                     14
# rApps         [YouTube, WhatsApp, Weather service, Android A...
# accepted                                                     39
# aApps         [Google, Telegram, Media Storage, com.quicinc....
# Name: 32, dtype: object
# permission    android.permission.PROVIDE_RESOLVER_RANKER_SER...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      2
# aApps          [Android Services Library, Google Play services]
# Name: 33, dtype: object
# permission                       android.permission.RECEIVE_SMS
# rejected                                                      3
# rApps                           [WhatsApp, Amazon Alexa, Phone]
# accepted                                                      9
# aApps         [Phone and MessagingStorage, Messages, Google ...
# Name: 34, dtype: object
# permission        android.permission.INTERACT_ACROSS_USERS_FULL
# rejected                                                      0
# rApps                                                        []
# accepted                                                     17
# aApps         [Phone and MessagingStorage, Nfc Service, Quic...
# Name: 35, dtype: object
# permission                android.permission.MODIFY_PHONE_STATE
# rejected                                                      0
# rApps                                                        []
# accepted                                                     16
# aApps         [Phone and MessagingStorage, Device setup, Set...
# Name: 36, dtype: object
# permission             android.permission.INTERACT_ACROSS_USERS
# rejected                                                      1
# rApps                                    [Google Contacts Sync]
# accepted                                                     26
# aApps         [Phone and MessagingStorage, Google, Media Sto...
# Name: 37, dtype: object
# permission                 android.permission.USE_RESERVED_DISK
# rejected                                                      0
# rApps                                                        []
# accepted                                                      9
# aApps         [Phone and MessagingStorage, Calendar Storage,...
# Name: 38, dtype: object
# permission    com.google.android.googleapps.permission.GOOGL...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      2
# aApps                            [Google, Google Contacts Sync]
# Name: 39, dtype: object
# permission    com.google.android.googleapps.permission.GOOGL...
# rejected                                                      3
# rApps         [Calendar Storage, Contacts, Google Play Movie...
# accepted                                                      8
# aApps         [Google, Gmail, Android Setup, Drive, Google C...
# Name: 40, dtype: object
# permission     android.permission.DOWNLOAD_WITHOUT_NOTIFICATION
# rejected                                                      0
# rApps                                                        []
# accepted                                                     15
# aApps         [Google, Messages, ConfigUpdater, WeChat, Gmai...
# Name: 41, dtype: object
# permission                    android.permission.WRITE_CALENDAR
# rejected                                                      1
# rApps                                                  [Any.do]
# accepted                                                      5
# aApps         [Google, Calendar Storage, Gmail, Calendar, Sh...
# Name: 42, dtype: object
# permission    com.android.browser.permission.WRITE_HISTORY_B...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      2
# aApps                                          [Google, Chrome]
# Name: 43, dtype: object
# permission    com.google.android.voicesearch.SHORTCUTS_ACCESS
# rejected                                                    1
# rApps                                                [Google]
# accepted                                                    0
# aApps                                                      []
# Name: 44, dtype: object
# permission    com.google.android.launcher.permission.RECEIVE...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      2
# aApps                            [Google, Google Play services]
# Name: 45, dtype: object
# permission    com.google.android.launcher.permission.RECEIVE...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      1
# aApps                                                  [Google]
# Name: 46, dtype: object
# permission    com.google.googlenav.friend.permission.OPT_IN
# rejected                                                  1
# rApps                                              [Google]
# accepted                                                  0
# aApps                                                    []
# Name: 47, dtype: object
# permission               android.permission.PACKAGE_USAGE_STATS
# rejected                                                      3
# rApps                          [Usage Logger, WeChat, My phone]
# accepted                                                     13
# aApps         [Google, com.hmdglobal.datago, Google Play Sto...
# Name: 48, dtype: object
# permission                   android.permission.CALL_PRIVILEGED
# rejected                                                      0
# rApps                                                        []
# accepted                                                      8
# aApps         [Google, Conference URI Dialer, Call Managemen...
# Name: 49, dtype: object
# permission    com.google.android.apps.gsa.nga.permissions.ED...
# rejected                                                      1
# rApps                                                  [Google]
# accepted                                                      0
# aApps                                                        []
# Name: 50, dtype: object
# permission    android.permission.SET_VOLUME_KEY_LONG_PRESS_L...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      1
# aApps                                                  [Google]
# Name: 51, dtype: object
# permission               com.android.alarm.permission.SET_ALARM
# rejected                                                      0
# rApps                                                        []
# accepted                                                      3
# aApps         [Google, com.qualcomm.qti.biometrics.fingerpri...
# Name: 52, dtype: object
# permission                        android.permission.MANAGE_USB
# rejected                                                      1
# rApps                                                  [Google]
# accepted                                                      6
# aApps         [MTP Host, Android Setup, Google Play services...
# Name: 53, dtype: object
# permission               android.permission.SET_WALLPAPER_HINTS
# rejected                                                      0
# rApps                                                        []
# accepted                                                      3
# aApps         [Google, com.android.wallpapercropper, Quickstep]
# Name: 54, dtype: object
# permission                 android.permission.CHANGE_WIFI_STATE
# rejected                                                      0
# rApps                                                        []
# accepted                                                     32
# aApps         [Google, QRCode, WhatsApp, Companion DeviceMan...
# Name: 55, dtype: object
# permission                         android.permission.GET_TASKS
# rejected                                                      0
# rApps                                                        []
# accepted                                                     15
# aApps         [Google, WhatsApp, Google Play Store, WeChat, ...
# Name: 56, dtype: object
# permission                     android.permission.SET_WALLPAPER
# rejected                                                      0
# rApps                                                        []
# accepted                                                     10
# aApps         [Google, com.android.wallpapercropper, Quickst...
# Name: 57, dtype: object
# permission    com.google.android.hangouts.START_HANGOUT
# rejected                                              2
# rApps                    [Google, Google Play services]
# accepted                                              0
# aApps                                                []
# Name: 58, dtype: object
# permission    com.google.android.gms.permission.ACTIVITY_REC...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      6
# aApps         [Google, Google Play Music, Digital Wellbeing,...
# Name: 59, dtype: object
# permission                          android.permission.READ_SMS
# rejected                                                      1
# rApps                                            [Amazon Alexa]
# accepted                                                      8
# aApps         [Google, MmsService, Messages, Google Play Sto...
# Name: 60, dtype: object
# permission                android.permission.READ_SYNC_SETTINGS
# rejected                                                      0
# rApps                                                        []
# accepted                                                     35
# aApps         [Google, Calendar Storage, Telegram, WhatsApp,...
# Name: 61, dtype: object
# permission                   android.permission.BLUETOOTH_ADMIN
# rejected                                                      0
# rApps                                                        []
# accepted                                                     26
# aApps         [Google, Companion DeviceManager, Factory Wiza...
# Name: 62, dtype: object
# permission    com.google.android.googlequicksearchbox.permis...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      2
# aApps                            [Google, Google Play services]
# Name: 63, dtype: object
# permission                      android.permission.READ_PROFILE
# rejected                                                      0
# rApps                                                        []
# accepted                                                     18
# aApps         [Google, Telegram, WhatsApp, Messages, WeChat,...
# Name: 64, dtype: object
# permission    com.google.android.apps.maps.permission.TIMELI...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      1
# aApps                                                  [Google]
# Name: 65, dtype: object
# permission    com.google.android.providers.settings.permissi...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      5
# aApps         [Google, Android Setup, Google Play services, ...
# Name: 66, dtype: object
# permission        android.permission.ACCESS_NOTIFICATION_POLICY
# rejected                                                      0
# rApps                                                        []
# accepted                                                      5
# aApps         [Google, WeChat, Camera, Digital Wellbeing, Go...
# Name: 67, dtype: object
# permission     com.android.launcher.permission.INSTALL_SHORTCUT
# rejected                                                      0
# rApps                                                        []
# accepted                                                     21
# aApps         [Google, Telegram, WhatsApp, Google Play Store...
# Name: 68, dtype: object
# permission                          android.permission.SEND_SMS
# rejected                                                      2
# rApps                                  [WhatsApp, Amazon Alexa]
# accepted                                                      9
# aApps         [Google, Messages, Google Play Store, AutoRegi...
# Name: 69, dtype: object
# permission                         android.permission.WRITE_SMS
# rejected                                                      0
# rApps                                                        []
# accepted                                                      6
# aApps         [Google, MmsService, Messages, AutoRegistratio...
# Name: 70, dtype: object
# permission                    android.permission.REAL_GET_TASKS
# rejected                                                      0
# rApps                                                        []
# accepted                                                      8
# aApps         [Google, Google Play Store, Nfc Service, Power...
# Name: 71, dtype: object
# permission           android.permission.MANAGE_VOICE_KEYPHRASES
# rejected                                                      0
# rApps                                                        []
# accepted                                                      5
# aApps         [Google, X Google enrollment, OK Google enroll...
# Name: 72, dtype: object
# permission                     android.permission.READ_CALL_LOG
# rejected                                                      1
# rApps                                                [Telegram]
# accepted                                                     10
# aApps         [Google, Conference URI Dialer, Glance, Phone,...
# Name: 73, dtype: object
# permission                         android.permission.BLUETOOTH
# rejected                                                      0
# rApps                                                        []
# accepted                                                     38
# aApps         [Google, Telegram, WhatsApp, Companion DeviceM...
# Name: 74, dtype: object
# permission    com.google.android.finsky.permission.DSE
# rejected                                             0
# rApps                                               []
# accepted                                             2
# aApps                      [Google, Google Play Store]
# Name: 75, dtype: object
# permission    android.permission.GLOBAL_SEARCH
# rejected                                     0
# rApps                                       []
# accepted                                     1
# aApps                                 [Google]
# Name: 76, dtype: object
# permission    com.google.android.apps.maps.permission.PREFETCH
# rejected                                                     0
# rApps                                                       []
# accepted                                                     2
# aApps                                           [Google, Maps]
# Name: 77, dtype: object
# permission    com.google.android.launcher.permission.WRITE_S...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      1
# aApps                                                  [Google]
# Name: 78, dtype: object
# permission    android.permission.MEDIA_CONTENT_CONTROL
# rejected                                             0
# rApps                                               []
# accepted                                             3
# aApps                   [Google, System UI, Bluetooth]
# Name: 79, dtype: object
# permission                     android.permission.READ_CALENDAR
# rejected                                                      2
# rApps                                        [Any.do, LinkedIn]
# accepted                                                      7
# aApps         [Google, Calendar Storage, Glance, Gmail, Goog...
# Name: 80, dtype: object
# permission    com.android.browser.permission.READ_HISTORY_BO...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      2
# aApps                                          [Google, Chrome]
# Name: 81, dtype: object
# permission    com.google.android.voicesearch.AUDIO_FILE_ACCESS
# rejected                                                     0
# rApps                                                       []
# accepted                                                     3
# aApps                              [Google, Gmail, Keep notes]
# Name: 82, dtype: object
# permission       android.permission.CHANGE_WIFI_MULTICAST_STATE
# rejected                                                      0
# rApps                                                        []
# accepted                                                      6
# aApps         [Google, WeChat, Default print service, Google...
# Name: 83, dtype: object
# permission    com.google.android.deskclock.permission.RECEIV...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      1
# aApps                                                  [Google]
# Name: 84, dtype: object
# permission                  android.permission.BROADCAST_STICKY
# rejected                                                      0
# rApps                                                        []
# accepted                                                     12
# aApps         [Google, WhatsApp, uceShimService, WeChat, FQC...
# Name: 85, dtype: object
# permission    android.permission.START_ACTIVITIES_FROM_BACKG...
# rejected                                                      4
# rApps         [Google, Google Play Store, Digital Wellbeing,...
# accepted                                                      0
# aApps                                                        []
# Name: 86, dtype: object
# permission    com.google.android.apps.googlevoice.permission...
# rejected                                                      1
# rApps                                                  [Google]
# accepted                                                      0
# aApps                                                        []
# Name: 87, dtype: object
# permission    com.google.android.providers.settings.permissi...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      5
# aApps         [Google, Android Setup, Google Play services, ...
# Name: 88, dtype: object
# permission    android.permission.USE_FULL_SCREEN_INTENT
# rejected                                              5
# rApps               [Google, WeChat, Clock, Duo, Phone]
# accepted                                              0
# aApps                                                []
# Name: 89, dtype: object
# permission    com.google.android.launcher.permission.CONTENT...
# rejected                                                      1
# rApps                                                  [Google]
# accepted                                                      0
# aApps                                                        []
# Name: 90, dtype: object
# permission                        android.permission.CALL_PHONE
# rejected                                                      4
# rApps               [QRCode, Quickstep, Amazon Alexa, Calendar]
# accepted                                                     16
# aApps         [Google, Telegram, Messages, Conference URI Di...
# Name: 91, dtype: object
# permission                        android.permission.FLASHLIGHT
# rejected                                                      0
# rApps                                                        []
# accepted                                                      7
# aApps         [Google, WeChat, FQC, Google Play services, Ti...
# Name: 92, dtype: object
# permission    com.google.android.voicesearch.ACCESS_SETTINGS
# rejected                                                   1
# rApps                                               [Google]
# accepted                                                   0
# aApps                                                     []
# Name: 93, dtype: object
# permission                 android.permission.STOP_APP_SWITCHES
# rejected                                                      0
# rApps                                                        []
# accepted                                                      8
# aApps         [Google, Nfc Service, Phone, Call Management, ...
# Name: 94, dtype: object
# permission    com.google.android.ears.permission.WRITE
# rejected                                             1
# rApps                                         [Google]
# accepted                                             0
# aApps                                               []
# Name: 95, dtype: object
# permission    com.android.browser.permission.PRELOAD
# rejected                                           1
# rApps                                       [Google]
# accepted                                           0
# aApps                                             []
# Name: 96, dtype: object
# permission                    android.permission.WRITE_CONTACTS
# rejected                                                      4
# rApps                           [WeChat, Duo, Photos, LinkedIn]
# accepted                                                     18
# aApps         [Google, Telegram, WhatsApp, Messages, Gmail, ...
# Name: 97, dtype: object
# permission    android.permission.SET_MEDIA_KEY_LISTENER
# rejected                                              0
# rApps                                                []
# accepted                                              1
# aApps                                          [Google]
# Name: 98, dtype: object
# permission    com.google.android.gm.permission.AUTO_SEND
# rejected                                               0
# rApps                                                 []
# accepted                                               2
# aApps                                    [Google, Gmail]
# Name: 99, dtype: object
# permission    com.android.chrome.PRERENDER_URL
# rejected                                     1
# rApps                                 [Google]
# accepted                                     0
# aApps                                       []
# Name: 100, dtype: object
# permission    com.google.android.googlequicksearchbox.permis...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      1
# aApps                                                  [Google]
# Name: 101, dtype: object
# permission    com.google.android.launcher.permission.READ_SE...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      1
# aApps                                                  [Google]
# Name: 102, dtype: object
# permission    android.permission.ANSWER_PHONE_CALLS
# rejected                                          2
# rApps                        [Google, Amazon Alexa]
# accepted                                          0
# aApps                                            []
# Name: 103, dtype: object
# permission    android.permission.CAPTURE_AUDIO_HOTWORD
# rejected                                             0
# rApps                                               []
# accepted                                             2
# aApps                   [Google, Google Play services]
# Name: 104, dtype: object
# permission        android.permission.BIND_APPWIDGET
# rejected                                          0
# rApps                                            []
# accepted                                          4
# aApps         [Google, Quickstep, Shell, System UI]
# Name: 105, dtype: object
# permission    com.google.android.googlequicksearchbox.permis...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      1
# aApps                                                  [Google]
# Name: 106, dtype: object
# permission              android.permission.CHANGE_NETWORK_STATE
# rejected                                                      0
# rApps                                                        []
# accepted                                                     19
# aApps         [Google, WhatsApp, Messages, Google Play Store...
# Name: 107, dtype: object
# permission    com.google.android.apps.now.CURRENT_ACCOUNT_AC...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      2
# aApps                                          [Google, Chrome]
# Name: 108, dtype: object
# permission          com.google.android.gm.permission.READ_GMAIL
# rejected                                                      1
# rApps                                                [Contacts]
# accepted                                                      5
# aApps         [Google, Gmail, Drive, Google Play services, C...
# Name: 109, dtype: object
# permission             android.permission.MODIFY_AUDIO_SETTINGS
# rejected                                                      0
# rApps                                                        []
# accepted                                                     22
# aApps         [Google, Telegram, WhatsApp, com.qualcomm.qti....
# Name: 110, dtype: object
# permission                    android.permission.WRITE_SETTINGS
# rejected                                                      3
# rApps                          [WeChat, Lightning QR, MapMyRun]
# accepted                                                     33
# aApps         [Google, Media Storage, Google Play Store, And...
# Name: 111, dtype: object
# permission                         android.permission.READ_LOGS
# rejected                                                      0
# rApps                                                        []
# accepted                                                      7
# aApps         [com.hmdglobal.datago, FQC, Stability Monitor,...
# Name: 112, dtype: object
# permission                              android.permission.DUMP
# rejected                                                      0
# rApps                                                        []
# accepted                                                      9
# aApps         [com.hmdglobal.datago, Google Play Store, FQC,...
# Name: 113, dtype: object
# permission              android.permission.UPDATE_APP_OPS_STATS
# rejected                                                      0
# rApps                                                        []
# accepted                                                     11
# aApps         [Calendar Storage, Download Manager, Package i...
# Name: 114, dtype: object
# permission                   android.permission.READ_SYNC_STATS
# rejected                                                      0
# rApps                                                        []
# accepted                                                     15
# aApps         [Calendar Storage, WhatsApp, Gmail, Duo, Googl...
# Name: 115, dtype: object
# permission               android.permission.WRITE_SYNC_SETTINGS
# rejected                                                      0
# rApps                                                        []
# accepted                                                     34
# aApps         [Calendar Storage, Telegram, WhatsApp, WeChat,...
# Name: 116, dtype: object
# permission             android.permission.SUBSCRIBED_FEEDS_READ
# rejected                                                      0
# rApps                                                        []
# accepted                                                     11
# aApps         [Calendar Storage, Camera, Gmail, Google Play ...
# Name: 117, dtype: object
# permission           android.permission.GET_ACCOUNTS_PRIVILEGED
# rejected                                                      0
# rApps                                                        []
# accepted                                                      5
# aApps         [Calendar Storage, Google Play Store, Phone, C...
# Name: 118, dtype: object
# permission            android.permission.SUBSCRIBED_FEEDS_WRITE
# rejected                                                      0
# rApps                                                        []
# accepted                                                     11
# aApps         [Calendar Storage, Camera, Gmail, Google Play ...
# Name: 119, dtype: object
# permission    com.google.android.googleapps.permission.GOOGL...
# rejected                                                      1
# rApps                                        [Calendar Storage]
# accepted                                                      0
# aApps                                                        []
# Name: 120, dtype: object
# permission    android.permission.INSTALL_SHORTCUT
# rejected                                        2
# rApps                        [Telegram, WhatsApp]
# accepted                                        0
# aApps                                          []
# Name: 121, dtype: object
# permission         com.anddoes.launcher.permission.UPDATE_COUNT
# rejected                                                     10
# rApps         [Telegram, Messages, Google Play Store, Duo, P...
# accepted                                                      0
# aApps                                                        []
# Name: 122, dtype: object
# permission          com.oppo.launcher.permission.WRITE_SETTINGS
# rejected                                                     10
# rApps         [Telegram, Messages, Google Play Store, Duo, P...
# accepted                                                      0
# aApps                                                        []
# Name: 123, dtype: object
# permission                    android.permission.READ_APP_BADGE
# rejected                                                     11
# rApps         [Telegram, Messages, Google Play Store, Duo, P...
# accepted                                                      0
# aApps                                                        []
# Name: 124, dtype: object
# permission          android.permission.REQUEST_INSTALL_PACKAGES
# rejected                                                     10
# rApps         [Telegram, WhatsApp, WeChat, Gmail, Files, Dri...
# accepted                                                      1
# aApps                                             [Nfc Service]
# Name: 125, dtype: object
# permission          com.majeur.launcher.permission.UPDATE_BADGE
# rejected                                                     10
# rApps         [Telegram, Messages, Google Play Store, Duo, P...
# accepted                                                      0
# aApps                                                        []
# Name: 126, dtype: object
# permission    me.everything.badger.permission.BADGE_COUNT_WRITE
# rejected                                                      6
# rApps         [Telegram, Polytopia, Trading Game, TikTok, In...
# accepted                                                      0
# aApps                                                        []
# Name: 127, dtype: object
# permission           com.oppo.launcher.permission.READ_SETTINGS
# rejected                                                     10
# rApps         [Telegram, Messages, Google Play Store, Duo, P...
# accepted                                                      0
# aApps                                                        []
# Name: 128, dtype: object
# permission             android.permission.AUTHENTICATE_ACCOUNTS
# rejected                                                      0
# rApps                                                        []
# accepted                                                     18
# aApps         [Telegram, WhatsApp, Authenticator, Google Pla...
# Name: 129, dtype: object
# permission    org.telegram.messenger.permission.MAPS_RECEIVE
# rejected                                                   0
# rApps                                                     []
# accepted                                                   1
# aApps                                             [Telegram]
# Name: 130, dtype: object
# permission    com.huawei.android.launcher.permission.WRITE_S...
# rejected                                                     12
# rApps         [Telegram, WhatsApp, Messages, Google Play Sto...
# accepted                                                      0
# aApps                                                        []
# Name: 131, dtype: object
# permission    com.android.launcher.permission.UNINSTALL_SHOR...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      7
# aApps         [Telegram, WhatsApp, WeChat, Drive, TikTok, An...
# Name: 132, dtype: object
# permission     me.everything.badger.permission.BADGE_COUNT_READ
# rejected                                                      6
# rApps         [Telegram, Polytopia, Trading Game, TikTok, In...
# accepted                                                      0
# aApps                                                        []
# Name: 133, dtype: object
# permission        android.permission.MANAGE_OWN_CALLS
# rejected                                            0
# rApps                                              []
# accepted                                            4
# aApps         [Telegram, WhatsApp, Amazon Alexa, Duo]
# Name: 134, dtype: object
# permission    com.huawei.android.launcher.permission.CHANGE_...
# rejected                                                     13
# rApps         [Telegram, WhatsApp, Messages, Google Play Sto...
# accepted                                                      0
# aApps                                                        []
# Name: 135, dtype: object
# permission                     android.permission.USE_BIOMETRIC
# rejected                                                      0
# rApps                                                        []
# accepted                                                      5
# aApps         [Telegram, WhatsApp, Google Play Store, Photos...
# Name: 136, dtype: object
# permission    com.huawei.android.launcher.permission.READ_SE...
# rejected                                                     12
# rApps         [Telegram, WhatsApp, Messages, Google Play Sto...
# accepted                                                      0
# aApps                                                        []
# Name: 137, dtype: object
# permission    android.permission.ACCESS_MTP
# rejected                                  0
# rApps                                    []
# accepted                                  1
# aApps                       [Media Storage]
# Name: 138, dtype: object
# permission                      android.permission.MANAGE_USERS
# rejected                                                      0
# rApps                                                        []
# accepted                                                     22
# aApps         [Media Storage, Google Play Store, Certificate...
# Name: 139, dtype: object
# permission               android.permission.WRITE_MEDIA_STORAGE
# rejected                                                      1
# rApps                                                  [Photos]
# accepted                                                     10
# aApps         [Media Storage, External Storage, org.codeauro...
# Name: 140, dtype: object
# permission    com.google.android.onetimeinitializer.permissi...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      1
# aApps                                    [Google One Time Init]
# Name: 141, dtype: object
# permission    android.permission.CHANGE_COMPONENT_ENABLED_STATE
# rejected                                                      0
# ...
# aApps                                  [Shell]
# Name: 699, dtype: object
# permission    android.permission.ACCESS_CONTENT_PROVIDERS_EX...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      1
# aApps                                                   [Shell]
# Name: 700, dtype: object
# permission    android.permission.MANAGE_CAMERA
# rejected                                     0
# rApps                                       []
# accepted                                     1
# aApps                                  [Shell]
# Name: 701, dtype: object
# permission    android.permission.CREATE_USERS
# rejected                                    0
# rApps                                      []
# accepted                                    1
# aApps                                 [Shell]
# Name: 702, dtype: object
# permission    android.permission.MANAGE_WIFI_WHEN_PERMISSION...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      1
# aApps                                                   [Shell]
# Name: 703, dtype: object
# permission    android.permission.MANAGE_BIND_INSTANT_SERVICE
# rejected                                                   0
# rApps                                                     []
# accepted                                                   1
# aApps                                                [Shell]
# Name: 704, dtype: object
# permission    android.permission.SET_ANIMATION_SCALE
# rejected                                           0
# rApps                                             []
# accepted                                           1
# aApps                                        [Shell]
# Name: 705, dtype: object
# permission    android.permission.FORCE_BACK
# rejected                                  0
# rApps                                    []
# accepted                                  1
# aApps                               [Shell]
# Name: 706, dtype: object
# permission    android.permission.SET_ORIENTATION
# rejected                                       0
# rApps                                         []
# accepted                                       2
# aApps                         [Shell, System UI]
# Name: 707, dtype: object
# permission    com.qti.snapdragon.sdk.permission.DISPLAY_SETT...
# rejected                                                      1
# rApps                                 [ColorTemperatureManager]
# accepted                                                      0
# aApps                                                        []
# Name: 708, dtype: object
# permission    android.hardware.camera.autofocus
# rejected                                      1
# rApps                     [Autodesk SketchBook]
# accepted                                      0
# aApps                                        []
# Name: 709, dtype: object
# permission    android.bluetooth.device.action.FOUND
# rejected                                          1
# rApps                                        [QMMI]
# accepted                                          0
# aApps                                            []
# Name: 710, dtype: object
# permission    android.permission.WRITE_OWNER_DATA
# rejected                                        1
# rApps                                      [QMMI]
# accepted                                        0
# aApps                                          []
# Name: 711, dtype: object
# permission    android.permission.MODIFY_THEME_OVERLAY
# rejected                                            0
# rApps                                              []
# accepted                                            1
# aApps                                     [System UI]
# Name: 712, dtype: object
# permission    android.permission.MANAGE_SLICE_PERMISSIONS
# rejected                                                0
# rApps                                                  []
# accepted                                                1
# aApps                                         [System UI]
# Name: 713, dtype: object
# permission    android.permission.RECEIVE_MEDIA_RESOURCE_USAGE
# rejected                                                    0
# rApps                                                      []
# accepted                                                    1
# aApps                                             [System UI]
# Name: 714, dtype: object
# permission    android.permission.TABLET_MODE
# rejected                                   0
# rApps                                     []
# accepted                                   1
# aApps                            [System UI]
# Name: 715, dtype: object
# permission    com.android.systemui.permission.SELF
# rejected                                         0
# rApps                                           []
# accepted                                         1
# aApps                                  [System UI]
# Name: 716, dtype: object
# permission    android.permission.NETWORK_STACK
# rejected                                     0
# rApps                                       []
# accepted                                     1
# aApps                              [System UI]
# Name: 717, dtype: object
# permission    android.permission.MANAGE_MEDIA_PROJECTION
# rejected                                               0
# rApps                                                 []
# accepted                                               1
# aApps                                        [System UI]
# Name: 718, dtype: object
# permission    android.permission.START_ANY_ACTIVITY
# rejected                                          0
# rApps                                            []
# accepted                                          1
# aApps                                   [System UI]
# Name: 719, dtype: object
# permission    android.permission.REMOTE_AUDIO_PLAYBACK
# rejected                                             0
# rApps                                               []
# accepted                                             1
# aApps                                      [System UI]
# Name: 720, dtype: object
# permission    android.permission.RESET_FINGERPRINT_LOCKOUT
# rejected                                                 0
# rApps                                                   []
# accepted                                                 1
# aApps                                          [System UI]
# Name: 721, dtype: object
# permission    android.permission.GET_TOP_ACTIVITY_INFO
# rejected                                             0
# rApps                                               []
# accepted                                             1
# aApps                                      [System UI]
# Name: 722, dtype: object
# permission    android.permission.RESET_SHORTCUT_MANAGER_THRO...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      1
# aApps                                               [System UI]
# Name: 723, dtype: object
# permission    android.permission.GET_INTENT_SENDER_INTENT
# rejected                                                0
# rApps                                                  []
# accepted                                                1
# aApps                                         [System UI]
# Name: 724, dtype: object
# permission    android.permission.MANAGE_APP_TOKENS
# rejected                                         0
# rApps                                           []
# accepted                                         1
# aApps                                  [System UI]
# Name: 725, dtype: object
# permission    android.permission.REGISTER_WINDOW_MANAGER_LIS...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      1
# aApps                                               [System UI]
# Name: 726, dtype: object
# permission    android.permission.CHANGE_ACCESSIBILITY_VOLUME
# rejected                                                   0
# rApps                                                     []
# accepted                                                   1
# aApps                                            [System UI]
# Name: 727, dtype: object
# permission    android.permission.CONTROL_DISPLAY_BRIGHTNESS
# rejected                                                  0
# rApps                                                    []
# accepted                                                  1
# aApps                                           [System UI]
# Name: 728, dtype: object
# permission    android.permission.WRITE_DREAM_STATE
# rejected                                         0
# rApps                                           []
# accepted                                         1
# aApps                                  [System UI]
# Name: 729, dtype: object
# permission    com.android.settings.fingerprint.permission.GE...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      1
# aApps                                               [System UI]
# Name: 730, dtype: object
# permission    android.car.permission.CAR_CONTROL_AUDIO_VOLUME
# rejected                                                    1
# rApps                                             [System UI]
# accepted                                                    0
# aApps                                                      []
# Name: 731, dtype: object
# permission    android.permission.ACCESS_VOICE_INTERACTION_SE...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      1
# aApps                                               [System UI]
# Name: 732, dtype: object
# permission    android.permission.BIND_QUICK_SETTINGS_TILE
# rejected                                                0
# rApps                                                  []
# accepted                                                1
# aApps                                         [System UI]
# Name: 733, dtype: object
# permission    android.permission.TRUST_LISTENER
# rejected                                      0
# rApps                                        []
# accepted                                      1
# aApps                               [System UI]
# Name: 734, dtype: object
# permission    android.permission.MODIFY_ACCESSIBILITY_DATA
# rejected                                                 0
# rApps                                                   []
# accepted                                                 1
# aApps                                          [System UI]
# Name: 735, dtype: object
# permission    android.permission.ACCESS_KEYGUARD_SECURE_STORAGE
# rejected                                                      0
# rApps                                                        []
# accepted                                                      1
# aApps                                               [System UI]
# Name: 736, dtype: object
# permission    com.qualcomm.permission.USE_PHONE_SERVICE
# rejected                                              1
# rApps                                      [ConfDialer]
# accepted                                              0
# aApps                                                []
# Name: 737, dtype: object
# permission    com.google.android.gms.game.notifications.perm...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      1
# aApps                                       [Google Play Games]
# Name: 738, dtype: object
# permission    android.permission.NET_ADMIN
# rejected                                 0
# rApps                                   []
# accepted                                 1
# aApps                          [Bluetooth]
# Name: 739, dtype: object
# permission    com.android.email.permission.READ_ATTACHMENT
# rejected                                                 1
# rApps                                          [Bluetooth]
# accepted                                                 0
# aApps                                                   []
# Name: 740, dtype: object
# permission    android.permission.BLUETOOTH_MAP
# rejected                                     0
# rApps                                       []
# accepted                                     1
# aApps                              [Bluetooth]
# Name: 741, dtype: object
# permission    android.permission.ACCESS_BLUETOOTH_SHARE
# rejected                                              0
# rApps                                                []
# accepted                                              1
# aApps                                       [Bluetooth]
# Name: 742, dtype: object
# permission    com.android.gallery3d.permission.GALLERY_PROVIDER
# rejected                                                      1
# rApps                                               [Bluetooth]
# accepted                                                      0
# aApps                                                        []
# Name: 743, dtype: object
# permission    android.permission.NET_TUNNELING
# rejected                                     0
# rApps                                       []
# accepted                                     1
# aApps                              [Bluetooth]
# Name: 744, dtype: object
# permission    com.google.android.gallery3d.permission.GALLER...
# rejected                                                      1
# rApps                                               [Bluetooth]
# accepted                                                      0
# aApps                                                        []
# Name: 745, dtype: object
# permission    com.android.email.permission.ACCESS_PROVIDER
# rejected                                                 1
# rApps                                          [Bluetooth]
# accepted                                                 0
# aApps                                                   []
# Name: 746, dtype: object
# permission    android.permission.PROCESS_PHONE_ACCOUNT_REGIS...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      1
# aApps                                        [Contacts Storage]
# Name: 747, dtype: object
# permission    android.permission.BIND_DIRECTORY_SEARCH
# rejected                                             0
# rApps                                               []
# accepted                                             1
# aApps                               [Contacts Storage]
# Name: 748, dtype: object
# permission    android.permission.SEND_CALL_LOG_CHANGE
# rejected                                            0
# rApps                                              []
# accepted                                            1
# aApps                              [Contacts Storage]
# Name: 749, dtype: object
# permission    com.google.android.apps.inputmethod.latin.perm...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      1
# aApps                                                  [Gboard]
# Name: 750, dtype: object
# permission    com.google.android.setupwizard.WRITE_DEVICE_OR...
# rejected                                                      0
# rApps                                                        []
# accepted                                                      1
# aApps                                           [Android Setup]
# Name: 751, dtype: object
